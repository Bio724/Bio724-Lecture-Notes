# %% [markdown]
# # Assignment: Simulating Boolean networks
#
# Name:
#
# NetID:

# %% [markdown]
# ## Readings
#
# Wang RS, Saadatpour A, Albert R. "Boolean modeling in systems biology: an overview of methodology and applications". *Phys Biol.* 2012 Oct;9(5):055001. PubMed PMID: 23011283  [DOI link](http://dx.doi.org/10.1088/1478-3975/9/5/055001).
#
#   * Focus primarily on Sections 1 and 2

# %% [markdown]
# ## Problem 1
#
# a. Write a set of Boolean functions to represent the network model illustrated below. [6 pts]
#
# ![saadatpour-alberts-figure.png](https://raw.githubusercontent.com/bio208fs-class/bio208fs-lecture/master/notebooks/saadatpour-alberts-figure.png)
#
# b. If you simulate the network from Problem 1a using a synchronous model, what are the state transition graphs you obtain and how many attractors are you able to identify from your simulations? Submit a PDF or PNG figure illustrating the state transition graphs. [6 pts]

# %% [markdown]
# ## Problem 2
#
# Submit your completed Jupyter notebook for the [Yeast Cell Cycle TF Boolean network modeling](https://github.com/Bio724/Bio724-Lecture-Notes/blob/main/lecture-simulation-python/yeast-cell-cycle-TF-network-blank.ipynb) exercise started in class. [12 pts total]
